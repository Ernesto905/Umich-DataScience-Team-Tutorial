# %% [markdown]
# # ML Challenge (Optional) THIS IS A WORK IN PROGRESS

# %% [markdown]
# Train, test, optimize, and analyze the performance of a classification model using a methodology of your choice for the randomly generated moons dataset.
#
# You are not being evaluated for the performance of your model. Instead, we are interested in whether you can implement a simple but rigorous ML workflow.
#
# Show all of your work in this notebook.

# %%
# you are free to use any package you deem fit
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Dataset

# %%
# DO NOT MODIFY
from sklearn.datasets import make_moons

# X: Features; inputs or predictors which the model uses to make predictions X is a set of coordinates
# Y: Labels; outputs or targets the model is trying to predict, Y is 0 or a 1
X, Y = make_moons(random_state=42, n_samples=(50, 450), noise=0.25)

# %% [markdown]
# ### Exploratory Data Analysis

# %%
import matplotlib.pyplot as plt

# Assuming `X` and `Y` have been generated using the make_moons function

plt.figure(figsize=(8, 5))  # Set the figure size
plt.scatter(X[:, 0], X[:, 1], c=Y, cmap=plt.cm.Spectral, edgecolor='k')  # Scatter plot of the two features in X, colored by Y
plt.title('Moons Dataset Visualization')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Training

# %%
# Will be using K-NN

# %% [markdown]
# ## Testing / Optimization

# %% [markdown]
# ## Performance Analysis
